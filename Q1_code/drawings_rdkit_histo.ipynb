# %%
#Yueyang Shen EECS476 Winter 2020
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import RDConfig
import os
from rdkit import DataStructs
from rdkit.Chem.Fingerprints import FingerprintMols
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from rdkit.Chem import PyMol
import cirpy

# %%
smi1 = cirpy.resolve('hydroxychloroquine', 'smiles')
smi2 = cirpy.resolve('hydroxychloroquine','smiles')
t = FingerprintMols.FingerprintMol(Chem.MolFromSmiles(smi1))
print(smi1)
m = FingerprintMols.FingerprintMol(Chem.MolFromSmiles(smi2))
z = Chem.MolFromSmiles(smi1)
print(DataStructs.FingerprintSimilarity(t,m,metric=DataStructs.TanimotoSimilarity))
z
# Out:
# CCN(CCO)CCCC(C)Nc1ccnc2cc(Cl)ccc12
# 1.0

# %%
#Histogram
import matplotlib.pyplot as plt
import numpy as np

similarity = np.zeros(6032)
i=0
with open('COVID19_disease_similarity.csv', 'r', encoding='utf-8') as f:
    for line in f:
        line_arr = line.split(',')
        #if i!=299:
        similarity[i] = line_arr[2]
        i += 1
    f.close()



rng = similarity  # deterministic random data
#a = np.hstack((rng.normal(size=1000),rng.normal(loc=5, scale=2, size=1000)))
_ = plt.hist(similarity, bins=20)  # arguments are passed to np.histogram
plt.title("Histogram for number of disease similar to COVID-19")
plt.xlabel("Similarity")
plt.ylabel("Number of disease")
plt.show()
